# %%
import pandas as pd
import pickle

# %%
question_info = pd.read_pickle('question_info.pkl')

# %%
question_info
# Out:
#                        questions_id          questions_date_added  \
# 0  ee5413617a51437f9d58a3d2f870d89b  2016-05-25 04:37:47 UTC+0000
# 1  cf215635476749c89e3d75cf24532a9c  2016-10-06 19:06:12 UTC+0000
# 2  12874ccefffe4b6fa4226f0792690642  2016-08-16 10:01:40 UTC+0000
# 3  c864355f2a654468aa3d4be79b0ee70c  2018-01-17 19:37:23 UTC+0000
# 4  d08a2430911f44d6917098bbcca412a8  2017-09-01 21:57:41 UTC+0000
# 5  898c7879dc1842bebdcd45a49a76e6fd  2016-07-21 04:03:00 UTC+0000
# 6  1500eea6b157405c802ad008bd232152  2017-02-10 12:48:46 UTC+0000
# 7  db8050a0c7ab4acd9c63b890fd66e5f3  2016-06-21 21:28:21 UTC+0000
# 8  7c9c284e305645fa9e53f524b9cc9381  2016-04-27 04:35:54 UTC+0000
# 9  04000a02ec2b44a9af7f310210921763  2016-05-02 04:03:58 UTC+0000
#
#                                      questions_title  \
# 0  If I still need more money to pay for college ...
# 1  What kind of master's degrees can I do if I am...
# 2  which subject i want to take for marketing ass...
# ...

# %%
with open('question_predictions.pkl', 'rb') as f:
    question_predictions = pickle.load(f)

# %%
question_predictions['ee5413617a51437f9d58a3d2f870d89b']
# Out:
#       score                  professionals_id          professionals_location  \
# 0  0.950841  20cadbf6b1494430b16230de160e2e89  Nairobi, Nairobi County, Kenya
# 1  0.951704  30f06b84e9c54b4ea0d4a402282e7878       Greater Philadelphia Area
# 2  0.953743  25e1b98f67b54df9a518881f6ffa98da               Detroit, Michigan
# 3  0.956137  793d64b966e648be9b3976f7d31cd3bf      Greater New York City Area
# 4  0.956824  2d830edb307c4747a000f3e24a1aca31         Los Angeles, California
# 5  0.962466  f8311f9ed5e242229c56996e9654ec6f       Greater Philadelphia Area
# 6  0.964904  b77eae0fb94d44b59082659da8541089        Greater Los Angeles Area
# 7  0.965000  0c1da6b3b5d441ddb4760a3a5f1246c3      Shenzhen, Guangdong, China
# 8  0.982019  d754969c1565445db381bb2d75273ee1        Greater Los Angeles Area
# 9  0.985609  36ff3b3666df400f956f8335cf53e09e                 Cleveland, Ohio
#
#   professionals_industry                             professionals_headline  \
# ...
